# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd  # libreria para analizar datos
import numpy as np   # libreria para calculos con arrays
import time          # libreria para ver el tiempo y la fecha
import matplotlib.pyplot as plt # libreria para plot
import seaborn as sns  # libreria para plot

# %%
#pip install diagrams

# %%
from google.colab import files
uploaded  = files.upload()
# Out:
#      <input type="file" id="files-2551a62f-038a-4d1d-9910-08a891b4e528" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2551a62f-038a-4d1d-9910-08a891b4e528">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Esta parte es estudiantes de marzo de 2017**

# %%
df = pd.read_excel(r'/home/jhcorrea/proyecto_utp/2017-marzo2172_mod.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-868a11eada8e> in <cell line: 0>()
# ----> 1 df = pd.read_excel(r'/home/jhcorrea/proyecto_utp/2017-marzo2172_mod.xlsx')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
result = df

# %%
forma = result.shape
print(forma)
print(' ')
columnas = result.columns
print(columnas)
valores_unicos = result.nunique()
print('')
print(valores_unicos)

# %%
#Contamos los valores vacios NaN
result.isna().sum()

# %%
# Eliminamos los datos que no tomaremos en cuenta
drop_cols = ['ID_CURSO', 'CATALOGO', 'NUMERO_CLASE', 'SECCION_CLASE', 'CICLO', 'COD_PROGRAMA', 'COD_PLAN', 'DEPARTAMENTO',
       'PROVINCIA']
data1 = result.drop(columns=drop_cols)
## Retiramos alumnos de provincias con el comando drop
data1 = data1.drop(data1[data1['CAMPUS']=='AREQU'].index)
data1 = data1.drop(data1[data1['CAMPUS']=='CHICL'].index)
data1 = data1.drop(data1[data1['CAMPUS']=='ICA'].index)
data1 = data1.drop(data1[data1['CAMPUS']=='PIURA'].index)
datan1 = data1

#Nuestra data ahora es datan1, ahora tenemos menos valores
datan1.nunique()

# %%
# Ahora eliminamos los datos que tienen NaN con dropna
datan0 = datan1.dropna()
datan0.nunique()
# Ahora veamos como quedo la forma final
# Ahora eliminamos los datos que tienen NaN con dropna
forma_nueva = datan0.shape
print(forma_nueva)
# Verificamos que no haya datos NaN
verificar_nan = datan0.isna().sum()
print(verificar_nan)

# %%
datan0.head()

# %%
datan0['DISTRITO'].unique()

# %%
# Aqui tenemos todos los valores de las variables de cada columna. count(0): fila, count(1): columna
datan0.count()

# %% [markdown]
# # **Esta parte es la data compilada de 2017 a 2019**

# %%
pip install dataframe_image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
localtime = time.asctime( time.localtime(time.time()) )

print('La hora en que se hace el código es :', localtime)
# Out:
# La hora en que se hace el código es : Tue Aug 22 18:17:19 2023

# %%
salida = pd.read_excel('Matriculados 2017 al 2019_mod.xlsx')
# Vemos la forma que presenta nuestro archivo de salida
salida.shape
# Out:
# (140054, 15)

# %%
salida.head()
# Out:
#   CAMPUS UN_NEG  ID_alumno SEXO  \
# 0  LIMAN    UTP      75802    M
# 1  LIMAN    UTP      75906    M
# 2  LIMAN    UTP      81125    F
# 3  LIMAN    UTP      90855    M
# 4   LIMA    UTP      73583    F
#
#                                          MODALIDAD     SUB_MODALIDAD  \
# 0  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 1  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 2  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 3                               Examen de Admisión  Examen Ordinario
# 4                               Examen de Admisión  Examen Ordinario
#
#        PERIODO   AÑO ANIO_PER_INGRESO DESC_GRADO COD_SUN COD_PROGRAMA  \
# 0  Ciclo Marzo  2019           2019-2        PPE     P60        PPCIV
# 1  Ciclo Marzo  2019           2018-3        PPE     P58        PPIND
# 2  Ciclo Marzo  2019           2018-3        PPE     P05        PADNE
# ...

# %%
# Hacemos una copia de la salida que tenemos
datan2 = salida.copy()

# %%
# Imprimimos la estrutura de las dos datas
print('data de salida:', datan2.shape)
print('data de entrada:',datan0.shape)
# Out:
# data de salida: (140054, 15)
# data de entrada: (37504, 11)

# %%
# Tenemos que tener el mismo nombre para las dos datas
datan2.rename(columns = {'ID_alumno':'ID_Alumno'}, inplace = True)
datan2.head()
# Out:
#   CAMPUS UN_NEG  ID_Alumno SEXO  \
# 0  LIMAN    UTP      75802    M
# 1  LIMAN    UTP      75906    M
# 2  LIMAN    UTP      81125    F
# 3  LIMAN    UTP      90855    M
# 4   LIMA    UTP      73583    F
#
#                                          MODALIDAD     SUB_MODALIDAD  \
# 0  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 1  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 2  Carrera para Gente que trabaja (semipresencial)      Admisión CGT
# 3                               Examen de Admisión  Examen Ordinario
# 4                               Examen de Admisión  Examen Ordinario
#
#        PERIODO   AÑO ANIO_PER_INGRESO DESC_GRADO COD_SUN COD_PROGRAMA  \
# 0  Ciclo Marzo  2019           2019-2        PPE     P60        PPCIV
# 1  Ciclo Marzo  2019           2018-3        PPE     P58        PPIND
# 2  Ciclo Marzo  2019           2018-3        PPE     P05        PADNE
# ...

# %%
#datan2[datan2['ID_Alumno']==1643]

# %%
#datan0['MODALIDAD_ENSEÑANZA']=datan2['MODALIDAD_ENSEÑANZA'].copy()

# %%
datan0
# Out:
#         ID_Alumno       SEXO  EDAD  PERIODO GRADO  \
# 4             321  MASCULINO  35.0     2172  PREG
# 5             667   FEMENINO  30.0     2172  PREG
# 6             667   FEMENINO  30.0     2172  PREG
# 19           1643   FEMENINO  28.0     2172  PREG
# 20           1643   FEMENINO  28.0     2172  PREG
# ...           ...        ...   ...      ...   ...
# 59908  9000000882   FEMENINO  26.0     2172  PREG
# 59920  9000001299  MASCULINO  33.0     2172   PPE
# 59921  9000001299  MASCULINO  33.0     2172   PPE
# 59922  9000001299  MASCULINO  33.0     2172   PPE
# 59923  9000001299  MASCULINO  33.0     2172   PPE
#
#                          NOMBRE_CURSO  PROMEDIO CAMPUS       TIPO_ADMISION  \
# 4      COMPRENSION Y REDACCION DE TEX        13   LIMA  EGRESADOS IDAT - P
# 5                            INGLES I         9   LIMA  EXAMEN DE ADMISIÓN
# 6                    ECONOMIA GENERAL        12   LIMA  EXAMEN DE ADMISIÓN
# ...

# %%
# colocando los distritos cercanos al campus LIMA
datan0['DISTRITO'] = datan0['DISTRITO'].replace(['LIMA','CALLAO','MIRAFLORES','JESUS MARIA','PUEBLO LIBRE', 'SAN BORJA','LA VICTORIA',
                                             'LA PERLA','MAGDALENA DEL MAR','RIMAC','SURQUILLO', 'SAN ISIDRO','SAN LUIS',
                                             'LINCE','BRENA','SAN MIGUEL','BARRANCO','CARMEN DE LA LEGUA-REYNOSO','BELLAVISTA',
                                             'LA PUNTA'], 'LIMA')
# colocando los distritos cercanos al campus LIMA NORTE
datan0['DISTRITO'] = datan0['DISTRITO'].replace(['COMAS','CARABAYLLO','PUENTE PIEDRA','ANCON','SAN MARTIN DE PORRES','LOS OLIVOS',
                                                 'VENTANILLA','INDEPENDENCIA'], 'LIMAN')
# colocando los distritos cercanos al campus LIMA SJL
datan0['DISTRITO'] = datan0['DISTRITO'].replace(['LURIGANCHO','SAN JUAN DE LURIGANCHO','SANTA ANITA',
                                             'EL AGUSTINO'], 'LISJL')
# colocando los distritos cercanos al campus LIMA SUR
datan0['DISTRITO'] = datan0['DISTRITO'].replace(['VILLA EL SALVADOR','PACHACAMAC','VILLA MARIA DEL TRIUNFO',
                                             'CHORRILLOS','PUCUSANA', 'LURIN','SAN BARTOLO', 'PUNTA HERMOSA'], 'LIMAS')
# colocando los distritos cercanos al campus LIMA ATE
datan0['DISTRITO'] = datan0['DISTRITO'].replace(['ATE','CIENEGUILLA','LA MOLINA','CHACLACAYO','SAN JUAN DE MIRAFLORES',
                                                 'SANTA EULALIA','SANTIAGO DE SURCO'], 'LIATE')
# Out:
# /tmp/ipykernel_995442/4263651642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['DISTRITO'] = datan0['DISTRITO'].replace(['LIMA','CALLAO','MIRAFLORES','JESUS MARIA','PUEBLO LIBRE', 'SAN BORJA','LA VICTORIA',
# /tmp/ipykernel_995442/4263651642.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['DISTRITO'] = datan0['DISTRITO'].replace(['COMAS','CARABAYLLO','PUENTE PIEDRA','ANCON','SAN MARTIN DE PORRES','LOS OLIVOS',
# ...

# %%
# Verificamos que los alumnos de diferentes campus coincidan con su lugar de distrito
datan0['address'] = (datan0['CAMPUS'] == datan0['DISTRITO'])
# renombramos la columna coincide con valores: 1 = coincide y 0 = no coincide
datan0['address'] = np.where(datan0['address']==True, 1, 0)
#datan0.head()
# Out:
# /tmp/ipykernel_995442/19325774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['address'] = (datan0['CAMPUS'] == datan0['DISTRITO'])
# /tmp/ipykernel_995442/19325774.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['address'] = np.where(datan0['address']==True, 1, 0)

# %%
# Verificamos que los alumnos de la data de entrada sigan matriculados en la data de salida
# Creamos una columna check
datan0['check'] = datan0['ID_Alumno'].isin(datan2['ID_Alumno'])
# Out:
# /tmp/ipykernel_995442/180157882.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['check'] = datan0['ID_Alumno'].isin(datan2['ID_Alumno'])

# %%
# creamos una columna 'salida' con resultados: 1 = continua y 0 = deserta
datan0['salida'] = np.where(datan0['check']==True, 1, 0)
datan0.head()
# Out:
# /tmp/ipykernel_995442/1533327506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['salida'] = np.where(datan0['check']==True, 1, 0)
#     ID_Alumno       SEXO  EDAD  PERIODO GRADO                    NOMBRE_CURSO  \
# 4         321  MASCULINO  35.0     2172  PREG  COMPRENSION Y REDACCION DE TEX
# 5         667   FEMENINO  30.0     2172  PREG                        INGLES I
# 6         667   FEMENINO  30.0     2172  PREG                ECONOMIA GENERAL
# 19       1643   FEMENINO  28.0     2172  PREG         INVESTIGACION ACADEMICA
# 20       1643   FEMENINO  28.0     2172  PREG                 QUIMICA GENERAL
#
#     PROMEDIO CAMPUS       TIPO_ADMISION DISTRITO  NRO_VEZ  address  check  \
# ...

# %%
#import dataframe_image as dfi
#import matplotlib.pyplot as plt
#import pandas as pd
#from pandas.table.plotting import table

# %%
#datan0.dfi.export('df.png')

#import plotly.figure_factory as ff # para crear como figura la tabla
#fig =  ff.create_table(datan0.head())
#fig.update_layout(
 #   autosize=False,
  #  width=500,
   # height=200,
#)
#fig.write_image("table_plotly.png", scale=2)
#fig.show()

# %%
#Vamos a colocar grado,distrito y tipo admision también como una varible
#PREG=0, PPE=1
datan0['GRADO'] = pd.factorize(datan0['GRADO'])[0].astype(np.uint16)
#datan0['DISTRITO'] = pd.factorize(datan0['DISTRITO'])[0].astype(np.uint16)
datan0['SEXO'] = pd.factorize(datan0['SEXO'])[0].astype(np.uint16)
# Out:
# /tmp/ipykernel_995442/2361586046.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['GRADO'] = pd.factorize(datan0['GRADO'])[0].astype(np.uint16)
# /tmp/ipykernel_995442/2361586046.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datan0['SEXO'] = pd.factorize(datan0['SEXO'])[0].astype(np.uint16)

# %%
# Podemos eliminar la columna check ya que no nos da ninguna información
datan0 = datan0.drop(columns=['check','NOMBRE_CURSO', 'PERIODO', 'TIPO_ADMISION','CAMPUS','DISTRITO'] )

# %%
datan0.head()
# Out:
#     ID_Alumno  SEXO  EDAD  GRADO  PROMEDIO  NRO_VEZ  address  salida
# 4         321     0  35.0      0        13      1.0        0       1
# 5         667     1  30.0      0         9      1.0        0       0
# 6         667     1  30.0      0        12      1.0        0       0
# 19       1643     1  28.0      0        12      1.0        0       1
# 20       1643     1  28.0      0        13      1.0        0       1

# %%
# from google.colab import files
# fig = plt.figure(figsize=(12,8))
# import dataframe_image as dfi

# datan0.head().style.highlight_max(axis=0).set_properties( **{'color': 'red'})

# dfi.export(
#     datan0.head(),
#     "table.png",
#     table_conversion="matplotlib"
# )
# #plt.savefig("table.png")
# #plt.show()

# %%
# cambiamos los nombres al ingles para el artículo
datan0.rename(columns = {'salida':'Dropout', 'EDAD':'Age','SEXO':'Gender','GRADO':'Worker','PROMEDIO':'Final Score'}, inplace = True)
datan0.head()
# Out:
#     ID_Alumno  Gender   Age  Worker  Final Score  NRO_VEZ  address  Dropout
# 4         321       0  35.0       0           13      1.0        0        1
# 5         667       1  30.0       0            9      1.0        0        0
# 6         667       1  30.0       0           12      1.0        0        0
# 19       1643       1  28.0       0           12      1.0        0        1
# 20       1643       1  28.0       0           13      1.0        0        1

# %%
datan0.rename(columns = {'NRO_VEZ':'Repeating'}, inplace = True)
datan0.head()
# Out:
#     ID_Alumno  Gender   Age  Worker  Final Score  Repeating  address  Dropout
# 4         321       0  35.0       0           13        1.0        0        1
# 5         667       1  30.0       0            9        1.0        0        0
# 6         667       1  30.0       0           12        1.0        0        0
# 19       1643       1  28.0       0           12        1.0        0        1
# 20       1643       1  28.0       0           13        1.0        0        1

# %%
#Dividiendo la data en masculino que desisten
datan0_masculino_desisten = datan0[(datan0['Gender'] == 0) & (datan0['Dropout'] == 0)]
#Dividiendo la data en masculino que continuan
datan0_masculino_siguen = datan0[(datan0['Gender'] == 0) & (datan0['Dropout'] == 1)]
#Dividiendo la data en femenino que continuan
datan0_femenino_desisten = datan0[(datan0['Gender'] == 1) & (datan0['Dropout'] == 0)]
#Dividiendo la data en femenino que continuan
datan0_femenino_siguen = datan0[(datan0['Gender'] == 1) & (datan0['Dropout'] == 1)]

# %%
datan0_masculino_desisten = datan0_masculino_desisten.pivot_table(index=['ID_Alumno', 'Worker', 'Gender'])
datan0_masculino_siguen = datan0_masculino_siguen.pivot_table(index=['ID_Alumno', 'Worker', 'Gender'])
datan0_femenino_desisten = datan0_femenino_desisten.pivot_table(index=['ID_Alumno', 'Worker', 'Gender'])
datan0_femenino_siguen = datan0_femenino_siguen.pivot_table(index=['ID_Alumno', 'Worker', 'Gender'])

# plotando los gráficos para cada subset de datos
fig, axes = plt.subplots(nrows=2, ncols=2, gridspec_kw={'wspace': 0.2},figsize=(15, 6))
datan0_masculino_desisten.head(20).plot(kind='bar',ax=axes[0,0]); axes[0,0].set_title('Male student dropout')
datan0_masculino_siguen.head(20).plot(kind='bar',ax=axes[0,1]); axes[0,1].set_title('Male student continue')
datan0_femenino_desisten.head(20).plot(kind='bar',ax=axes[1,0]); axes[1,0].set_title('Female student dropout')
datan0_femenino_siguen.head(20).plot(kind='bar',ax=axes[1,1]); axes[1,1].set_title('Female student continue')
fig.subplots_adjust(hspace=1.5)
#datan0_masculino_desisten.head(30).plot(kind='bar',figsize=(15, 8))
#datan0_masculino_siguen.head(20).plot(kind='bar')
#datan0_femenino_desisten.head(20).plot(kind='bar')
#datan0_femenino_siguen.head(5).plot(kind='bar')
#plt.show()

# %%
data_final = datan0.pivot_table(index=['ID_Alumno'])
data_final.head(10).plot(kind='bar',figsize=(10,8),fontsize=12)
plt.xlabel("ID Student",fontsize=14)
#fig.set_size_inches(18.5, 10.5, forward=True)
#plt.savefig("test.png",bbox_inches='tight')

#plt.savefig('barra.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
plt.savefig('barra.pdf',bbox_inches='tight')
files.download('barra.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 9>()
#       4 #fig.set_size_inches(18.5, 10.5, forward=True)
#       5 #plt.savefig("test.png",bbox_inches='tight')
#       6
#       7 #plt.savefig('barra.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
#       8 plt.savefig('barra.pdf',bbox_inches='tight')
# ----> 9 files.download('barra.pdf')
#
# NameError: name 'files' is not defined

# %%
data_final
# Out:
#              Age  Dropout  Final Score  Gender  Repeating  Worker  address
# ID_Alumno
# 321         35.0        1    13.000000       0        1.0       0        0
# 667         30.0        0    10.500000       1        1.0       0        0
# 1643        28.0        1    12.500000       1        1.0       0        0
# 2112        28.0        1    14.250000       0        1.0       0        1
# 3770        36.0        1    15.166667       1        1.0       1        0
# ...          ...      ...          ...     ...        ...     ...      ...
# 487874      33.0        1    13.500000       1        1.0       0        1
# 9000000155  29.0        1    15.500000       0        1.0       0        1
# 9000000433  32.0        0    18.000000       0        1.0       0        0
# 9000000882  26.0        0    10.750000       1        1.5       0        1
# 9000001299  33.0        1     7.750000       0        1.0       1        1
#
# [8294 rows x 7 columns]

# %%
#data_final.rename(columns = {'Dropout':'y'}, inplace = True)
#data_final.head()

# %%
#X = data_final.drop(['y'], axis=1)
#y = data_final.y

# %%
data_final.Dropout.value_counts()
# Out:
# 1    6705
# 0    1589
# Name: Dropout, dtype: int64

# %%
import seaborn as sns
ax= sns.countplot(x='Dropout', data=data_final)
#plt.savefig('graficos.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
plt.savefig('graficos.pdf',bbox_inches='tight')

# files.download('graficos.pdf')

# %%
#faremos um teste
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
X= data_final.drop('Dropout',axis=1)
y= data_final.Dropout

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, stratify=y)
lr.fit(X_train,y_train)
y_pred= lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, f1_score
from sklearn.metrics import classification_report


accuracy_score(y_test, y_pred)
# Out:
# 0.9199614271938283

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       397
#            1       0.91      1.00      0.95      1677
#
#     accuracy                           0.92      2074
#    macro avg       0.95      0.79      0.85      2074
# weighted avg       0.93      0.92      0.91      2074

# %%
print(pd.crosstab(y_test, y_pred, rownames=['Real'],colnames=['Predito'], margins= True))
# Out:
# Predito    0     1   All
# Real
# 0        233   164   397
# 1          2  1675  1677
# All      235  1839  2074

# %%
from imblearn.over_sampling._smote.base import SMOTEN
from imblearn.under_sampling import NearMiss
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE,ADASYN,SMOTENC, BorderlineSMOTE



#under_sampler = RandomUnderSampler()
#nr= NearMiss()
smt= SMOTE(random_state = 101)
#smtnc= SMOTENC()
bsmote= BorderlineSMOTE()
ada= ADASYN(random_state=101)

# %%
#X,y= nr.fit_resample(X,y)
# X,y= ada.fit_resample(X,y)
#X, y = under_sampler.fit_resample(X,y)

# %%
ax= sns.countplot(x=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=101, stratify=y)
lr.fit(X_train,y_train)
y_pred= lr.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.914175506268081

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71       397
#            1       0.90      1.00      0.95      1677
#
#     accuracy                           0.91      2074
#    macro avg       0.95      0.78      0.83      2074
# weighted avg       0.92      0.91      0.90      2074

# %%
print(pd.crosstab(y_test, y_pred, rownames=['Real'],colnames=['Predito'], margins= True))
# Out:
# Predito    0     1   All
# Real
# 0        219   178   397
# 1          0  1677  1677
# All      219  1855  2074

# %%
#f,ax=plt.subplots(1,2,figsize=(18,8))
#data_final['Dropout'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
#ax[0].set_title('Students')
#ax[0].set_ylabel('')
#sns.countplot('Dropout',data=data_final,ax=ax[1])
#ax[1].set_title('Students')
#plt.show()

# %%
#fig1, ax1 = plt.subplots()
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
 #       shadow=True, startangle=90)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

#plt.show()

#fig1, ax1 = plt.subplots()
#plot = data_final['Dropout'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)

# %%
#f, ax = plt.subplots(1,2,figsize=(18,8))

#data_final['Dropout'].value_counts().plot(kind='pie',
 #   explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True
#)
#ax[0].set_title('Pie plot-Survived')
#ax[0].set_ylabel('')

#sns.countplot(x=df["class"])
#sns.countplot(x=data_final["Dropout"], ax=ax[1])
#sns.countplot('Dropout', data=data_final, ax=ax[1])
#ax[1].set_title('Count plot - Survived')

#plt.show()

# %%
#insurance_ds = pd.DataFrame({'sex':np.random.choice(['male','female'],1000)})
#insurance_ds['sex'] = pd.Categorical(insurance_ds['sex'],categories=['male','female'])
#fig, ax = plt.subplots(1,2,figsize=(10,5))
#sns.countplot("Dropout",data=data_final,ax=ax[1])
#data_final["Dropout"].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,textprops={'fontsize': 10},ax=ax[0])

# %%
#sns.pairplot(data_final)

# %%
# verificamos que no haya ningún valor Nan
valores_nan_final = datan0.isna().sum()
print(valores_nan_final)
print(' ')
# Out:
# ID_Alumno      0
# Gender         0
# Age            0
# Worker         0
# Final Score    0
# Repeating      0
# address        0
# Dropout        0
# dtype: int64

# %%
data_prueba= data_final.head(130)

# %% [markdown]
# # **Machine Learning**

# %% [markdown]
# En esta parte vamos a hacer uso de los modelos predictivos para predecir si un alumno desiste o no

# %%
pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cargamos todas las librerias necesarias para el machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import NuSVC
import matplotlib as mpl
# from keras.models import Sequential
# from keras.layers import Dense
#from sklearn.neural_network import MLPClassifier
from sklearn import svm
#from sklearn.naive_bayes import GaussianNB
# from xgboost import XGBRegressor

from sklearn.ensemble import BaggingClassifier

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import TomekLinks

#from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import classification_report #metricas de validação
#from sklearn.metrics import auc, plot_precision_recall_curve
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay

# %%
# Colores para plot
colores =['Greens', 'Blues', 'Reds',  'OrRd', 'Purples', 'PuRd', 'BuGn', 'YlGn','YlGn']
# Nombre de los modelos predictivos
#names=['KNN','SVC','NuSVC','Decision Tree', 'MPL Classifier','Random Forest', 'AdaBoost',
 #       'GradientBoostingClassifier', 'Gaussian', 'Quadratic','Logistic Regression'] #XGBoost
names=['KNN','Decision Tree', 'Random Forest', 'AdaBoost',
        'GradientBoostingClassifier','Logistic Regression']
# Modelos prodictivos
classifiers = [
    KNeighborsClassifier(3), #knn
    #svm.SVC(kernel="rbf", C=0.025, probability=True),
    #NuSVC(probability=True),
    DecisionTreeClassifier(criterion='entropy',max_depth=4, random_state=0), #Árvore de Decisão
    #MLPClassifier(max_iter=300, learning_rate_init= 0.1,alpha=0.01), #rede neural
    RandomForestClassifier(n_estimators=100, random_state=0), #Random Forest
    AdaBoostClassifier(n_estimators=100,random_state=0),
    GradientBoostingClassifier(n_estimators=100, max_features=2, max_depth=2), #Gradient Boosting
    #GaussianNB(), #Naive Bayes
   # LinearDiscriminantAnalysis(),
    #QuadraticDiscriminantAnalysis(),
    LogisticRegression(), #Regressão Logística

]

# %% [markdown]
# ***ESTA PARTE ES CONSIDERANDO DATA DESBALANCEADA***

# %%
#colocando los X e y a través de la data final
#en esta parte solo estamos eliminando Dropout en X
X = data_final.drop(['Dropout'], axis=1)
y = data_final['Dropout']

# Tratar de balancear la data
rus = RandomUnderSampler(random_state=0)
ros = RandomUnderSampler(random_state=0)
#smt= SMOTE()
#nr= NearMiss()
#ndersample = CondensedNearestNeighbour(n_neighbors=1)
#undersample = TomekLinks()
#X_resampled_ros, y_resampled_ros = ros.fit_resample(X,y)
# Dividiendo la data en entrenamiento y prueba
#X, y = smt.fit_resample(X, y)
#X,y= nr.fit_resample(X,y)

# %%
ax= sns.countplot(x=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                    random_state=0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#X_train_resampled_ros, y_train_resampled_ros = smote.fit_resample(X_train,y_train)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (4976, 6) (4976,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                    random_state=0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#X_train_resampled_ros, y_train_resampled_ros = smote.fit_resample(X_train,y_train)

# %%
# Colocaremos todos los modelos en una sola función

nombre = []
################Previsão considerando todos os observaveis
#for cclf in classifiers:
for color, clf in zip(colores,classifiers):
        #Executando o treino (treino)
        #clf1= BaggingClassifier(base_stimator=clf, estimators=10,
         #                       random_state=0).fit(X_train_resampled_ros, y_train_resampled_ros)

        clf.fit(X_train, y_train)
        name = clf.__class__.__name__
        nombre.append(name)
        print(name)
        #accuracy
        train_predictions = clf.predict(X_test) #Executando teste
        acc = accuracy_score(y_test, train_predictions) # Verifica o accuracy
        print("Probabilidad de la acuracia: {:.4%}".format(acc))

        #score
        scores = cross_val_score(clf, X_train, y_train, cv=10)
        print('Cross-Validation Accuracy Scores', scores)

        print('roc_auc_score - ', roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
        print('accuracy_score - ', accuracy_score(y_test, clf.predict(X_test)))
        print('recall_score - ', recall_score(y_test, clf.predict(X_test)))
        print('precision_score - ', precision_score(y_test, clf.predict(X_test)))
        print('Misclassification Rate -', 1- accuracy_score(y_test, clf.predict(X_test)))


        #print(' ')
        #print(' ')
        clf_roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])
        fpr_clf, tpr_clf, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])


        fig, ax = plt.subplots(figsize=(8,6))
        plot_labels = ['mantiene', 'retira']
        tick_marks = np.arange(len(plot_labels))
        sns.heatmap(confusion_matrix(y_test, clf.predict(X_test), normalize=None),
             cmap=plt.cm.get_cmap(color),
             annot=True,
             cbar=True,
             fmt='g',
             ax=ax);
        ax.set_title(f'Confusion matrix -{name}'  )
        #ax.set_title(name  )
        ax.set_ylabel('TRUE LABEL')
        ax.set_xlabel('PREDICTED LABEL')
        ax.figure.savefig('confusionmatrix.pdf')

       #clf_roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])
       #fpr_clf, tpr_clf, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
        #fig, ax = plt.subplots(1, 1, figsize=(8,5))

        #plt.plot(fpr_clf, tpr_clf, label=f'{name} (area = %.2f)' % clf_roc_auc)

        #plt.plot(([0,0], [1,1]), '--');

        #plt.title(f'ROC curve-{name}')
        #plt.xlim([-0.01, 1.01])
        #plt.ylim([-0.01, 1.01])

        #plt.xlabel('False Positive Rate')
        #plt.ylabel('True Positive Rate')
        #plt.legend(loc='lower right');
# Out:
# KNeighborsClassifier
# Probabilidad de la acuracia: 90.4762%
# Cross-Validation Accuracy Scores [0.90361446 0.8935743  0.90763052 0.88554217 0.90963855 0.92168675
#  0.89738431 0.87927565 0.91348089 0.89537223]
# roc_auc_score -  0.823405272929818
# accuracy_score -  0.9047619047619048
# recall_score -  0.9699220200519866
# precision_score -  0.9174569722514928
# Misclassification Rate - 0.09523809523809523
# /tmp/ipykernel_995442/442139444.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap(color),
# /tmp/ipykernel_995442/442139444.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap(color),
# ...

# %%
#names=['KKN','SVC','NuSVC','Decision Tree', 'MPL Classifier','Random Forest', 'AdaBoost',
 #       'GradientBoostingClassifier', 'Gaussian', 'Quadratic','Logistic Regression']
#names=['Decision Tree', 'Random Forest', 'AdamBoost',
  #      'Gradient Boost']
model_cols=[]
df = pd.DataFrame(columns= model_cols)
index=0
for nombre, clf in zip(names,classifiers):
  clf.fit(X_train, y_train)
  df.loc[index,'Classifiers'] = nombre
  df.loc[index, 'Train accuracy']= clf.score(X_train,y_train)
  df.loc[index, 'Test accuracy']= clf.score(X_test,y_test)
  df.loc[index, 'Precision']= precision_score(y_test, clf.predict(X_test))
  df.loc[index, 'Recall']= recall_score(y_test,clf.predict(X_test))
  df.loc[index, 'F1 score']= f1_score(y_test,clf.predict(X_test))
  index +=1
print(df)
# Out:
#                   Classifiers  Train accuracy  Test accuracy  Precision  \
# 0                         KNN        0.924437       0.904762   0.917457
# 1               Decision Tree        0.918207       0.924352   0.915589
# 2               Random Forest        0.954180       0.901748   0.923132
# 3                    AdaBoost        0.919011       0.925558   0.917406
# 4  GradientBoostingClassifier        0.919815       0.925859   0.917150
# 5         Logistic Regression        0.918006       0.924653   0.915618
#
#      Recall  F1 score
# 0  0.969922  0.942960
# 1  0.998886  0.955425
# 2  0.958782  0.940619
# 3  0.998143  0.956073
# 4  0.998886  0.956274
# 5  0.999257  0.955611

# %%
#from google.colab import files
# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for i,cls in zip(names,classifiers):
    model = cls.fit(X_train, y_train)
    yproba = model.predict_proba(X_test)[::,1]

    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)

    result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
                                        'fpr':fpr,
                                        'tpr':tpr,
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

figure = plt.gcf()

figure.set_size_inches(12, 8)#fig = plt.figure(figsize=(12,8))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'],
             result_table.loc[i]['tpr'],
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))

plt.plot([0,1], [0,1], color='blue', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1),fontsize=14)
plt.xlabel("False Positive Rate", fontsize=20)

plt.yticks(np.arange(0.0, 1.1, step=0.1),fontsize=14)
plt.ylabel("True Positive Rate", fontsize=20)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

#plt.show()
#plt.savefig('ROC_desbalanceada.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
plt.savefig('ROC_desbalanceada.pdf',bbox_inches='tight')

#files.download('ROC_desbalanceada.pdf')
plt.show()
# Out:
# /tmp/ipykernel_995442/2901474300.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/2901474300.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/2901474300.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/2901474300.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ***ESTA PARTE CONSIDERA DATA BALANCEADA EL OVERSAMPLING - AUMENTANDO DATA***

# %%
#colocando los X e y a través de la data final
#en esta parte solo estamos eliminando Dropout en X
X_over = data_final.drop(['Dropout'], axis=1)
y_over = data_final['Dropout']

# Tratar de balancear la data
under_sampler = RandomUnderSampler()
smt= SMOTE()
#nr= NearMiss()
#ndersample = CondensedNearestNeighbour(n_neighbors=1)
#undersample = TomekLinks()
#X_resampled_ros, y_resampled_ros = ros.fit_resample(X,y)
# Dividiendo la data en entrenamiento y prueba
X_over,y_over= smt.fit_resample(X_over,y_over)

# %%
ax= sns.countplot(x=y_over)
#plt.savefig('igualdad.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
#files.download('igualdad.pdf')

# %%
X_train_over, X_test_over, y_train_over, y_test_over = train_test_split(X_over,y_over, random_state=101, stratify=y_over)#(X_under, y_under, test_size=0.4,
                                                  #  random_state=0)

sc = StandardScaler()
X_train_over = sc.fit_transform(X_train_over)
X_test_over = sc.transform(X_test_over)

#X_train_resampled_ros, y_train_resampled_ros = smote.fit_resample(X_train,y_train)

# %%
print(X_train_over.shape,y_train_over.shape)
# Out:
# (10057, 6) (10057,)

# %%
# Colocaremos todos los modelos en una sola función

nombre = []
################Previsão considerando todos os observaveis
#for cclf in classifiers:
for color, clf in zip(colores,classifiers):
        #Executando o treino (treino)
        #clf1= BaggingClassifier(base_stimator=clf, estimators=10,
         #                       random_state=0).fit(X_train_resampled_ros, y_train_resampled_ros)

        clf.fit(X_train_over, y_train_over)
        name = clf.__class__.__name__
        nombre.append(name)
        print(name)
        #accuracy
        train_predictions = clf.predict(X_test_over) #Executando teste
        acc = accuracy_score(y_test_over, train_predictions) # Verifica o accuracy
        print("Probabilidad de la acuracia: {:.4%}".format(acc))

        #score
        scores = cross_val_score(clf, X_train_over, y_train_over, cv=10)
        print('Cross-Validation Accuracy Scores', scores)

        print('roc_auc_score - ', roc_auc_score(y_test_over, clf.predict_proba(X_test_over)[:,1]))
        print('accuracy_score - ', accuracy_score(y_test_over, clf.predict(X_test_over)))
        print('recall_score - ', recall_score(y_test_over, clf.predict(X_test_over)))
        print('precision_score - ', precision_score(y_test_over, clf.predict(X_test_over)))
        print('Misclassification Rate -', 1- accuracy_score(y_test_over, clf.predict(X_test_over)))


        #print(' ')
        #print(' ')
        clf_roc_auc = roc_auc_score(y_test_over, clf.predict_proba(X_test_over)[:,1])
        fpr_clf, tpr_clf, _ = roc_curve(y_test_over, clf.predict_proba(X_test_over)[:,1])


        fig, ax = plt.subplots(figsize=(8,6))
        plot_labels = ['mantiene', 'retira']
        tick_marks = np.arange(len(plot_labels))
        sns.heatmap(confusion_matrix(y_test_over, clf.predict(X_test_over), normalize=None),
             cmap=plt.cm.get_cmap(color),
             annot=True,
             cbar=True,
             fmt='g',
             ax=ax);
        ax.set_title(name  )
        ax.set_ylabel('TRUE LABEL')
        ax.set_xlabel('PREDICTED LABEL')
        ax.figure.savefig('confusionmatrix.png')

       #clf_roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])
       #fpr_clf, tpr_clf, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
        #fig, ax = plt.subplots(1, 1, figsize=(8,5))

        #plt.plot(fpr_clf, tpr_clf, label=f'{name} (area = %.2f)' % clf_roc_auc)

        #plt.plot(([0,0], [1,1]), '--');

        #plt.title(f'ROC curve-{name}')
        #plt.xlim([-0.01, 1.01])
        #plt.ylim([-0.01, 1.01])

        #plt.xlabel('False Positive Rate')
        #plt.ylabel('True Positive Rate')
        #plt.legend(loc='lower right');
# Out:
# KNeighborsClassifier
# Probabilidad de la acuracia: 85.8634%
# Cross-Validation Accuracy Scores [0.84890656 0.86481113 0.86282306 0.84095427 0.85387674 0.84393638
#  0.85785288 0.84975124 0.86368159 0.86467662]
# roc_auc_score -  0.918626176417429
# accuracy_score -  0.8586340590515956
# recall_score -  0.8872987477638641
# precision_score -  0.8392554991539763
# Misclassification Rate - 0.14136594094840438
# /tmp/ipykernel_995442/1248289728.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap=plt.cm.get_cmap(color),
# DecisionTreeClassifier
# Probabilidad de la acuracia: 84.9090%
# Cross-Validation Accuracy Scores [0.84095427 0.85089463 0.86182903 0.85089463 0.85089463 0.84095427
#  0.85984095 0.85671642 0.83781095 0.86965174]
# roc_auc_score -  0.8831876020225913
# accuracy_score -  0.8490903668356695
# ...

# %%
#names=['KKN','SVC','NuSVC','Decision Tree', 'MPL Classifier','Random Forest', 'AdaBoost',
 #       'GradientBoostingClassifier', 'Gaussian', 'Quadratic','Logistic Regression']
#names=['Decision Tree', 'Random Forest', 'AdamBoost',
 #       'Gradient Boost']
model_cols_over=[]
df_over = pd.DataFrame(columns= model_cols_over)
index=0
for nombres, clf in zip(names,classifiers):
  clf.fit(X_train_over, y_train_over)
  df_over.loc[index,'Classifiers'] = nombres
  df_over.loc[index, 'Train accuracy']= clf.score(X_train_over,y_train_over)
  df_over.loc[index, 'Test accuracy']= clf.score(X_test_over,y_test_over)
  df_over.loc[index, 'Precision']= precision_score(y_test_over, clf.predict(X_test_over))
  df_over.loc[index, 'Recall']= recall_score(y_test_over,clf.predict(X_test_over))
  df_over.loc[index, 'F1 score']= f1_score(y_test_over,clf.predict(X_test_over))
  index +=1
print(df_over)
# Out:
#                   Classifiers  Train accuracy  Test accuracy  Precision  \
# 0                         KNN        0.919061       0.858634   0.839255
# 1               Decision Tree        0.852541       0.849090   0.777357
# 2               Random Forest        0.961818       0.883388   0.868270
# 3                    AdaBoost        0.857810       0.852967   0.782173
# 4  GradientBoostingClassifier        0.853634       0.850880   0.776421
# 5         Logistic Regression        0.831262       0.834477   0.752022
#
#      Recall  F1 score
# 0  0.887299  0.862609
# 1  0.978533  0.866420
# 2  0.903995  0.885773
# 3  0.978533  0.869404
# 4  0.985689  0.868628
# 5  0.998211  0.857802

# %%
#from google.colab import files
# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for i,cls in zip(names,classifiers):
    model = cls.fit(X_train_over, y_train_over)
    yproba = model.predict_proba(X_test_over)[::,1]

    fpr, tpr, _ = roc_curve(y_test_over,  yproba)
    auc = roc_auc_score(y_test_over, yproba)

    result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
                                        'fpr':fpr,
                                        'tpr':tpr,
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

figure = plt.gcf()

figure.set_size_inches(12, 8)#fig = plt.figure(figsize=(12,8))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'],
             result_table.loc[i]['tpr'],
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))

plt.plot([0,1], [0,1], color='blue', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1),fontsize=14)
plt.xlabel("False Positive Rate", fontsize=20)

plt.yticks(np.arange(0.0, 1.1, step=0.1),fontsize=14)
plt.ylabel("True Positive Rate", fontsize=20)


plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

#plt.show()
#plt.savefig('ROC_balanceada.pdf',dpi=300,optimize=True, progressive=True,bbox_inches='tight')
plt.savefig('ROC_balanceada.pdf',bbox_inches='tight')

#files.download('ROC_balanceada.pdf')
plt.show()
# Out:
# /tmp/ipykernel_995442/527780660.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/527780660.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/527780660.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_table = result_table.append({'classifiers':i,#cls.__class__.__name__,
# /tmp/ipykernel_995442/527780660.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# Here is the Precision - Recall Curve

# %%
# En esta parte vamos a colocar los métodos para compararlos
for model in classifiers:
  #print('accuracy for {}: {}'.format((model), model.score(X_test,y_test)))
  y_pred= model.predict(X_test)
  y_true = y_test
  print('*************** {} ***********\n'.format(model))
  cm =confusion_matrix(y_true, y_pred)
  print(cm)
# Out:
# *************** KNeighborsClassifier(n_neighbors=3) ***********
#
# [[ 586   39]
#  [1499 1194]]
# *************** DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0) ***********
#
# [[ 625    0]
#  [2693    0]]
# *************** RandomForestClassifier(random_state=0) ***********
#
# [[ 625    0]
#  [2693    0]]
# *************** AdaBoostClassifier(n_estimators=100, random_state=0) ***********
#
# [[ 625    0]
#  [2693    0]]
# *************** GradientBoostingClassifier(max_depth=2, max_features=2) ***********
#
# [[ 625    0]
#  [2693    0]]
# *************** LogisticRegression() ***********
#
# [[ 619    6]
#  [2554  139]]

# %%
for model in classifiers:
  #print('accuracy for {}: {}'.format((model), model.score(X_test,y_test)))
  y_pred_over= model.predict(X_test_over)
  y_true_over = y_test_over
  print('*************** {} ***********\n'.format(model))
  cm =confusion_matrix(y_true_over, y_pred_over)
  print(cm)
# Out:
# *************** KNeighborsClassifier(n_neighbors=3) ***********
#
# [[1391  285]
#  [ 189 1488]]
# *************** DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0) ***********
#
# [[1206  470]
#  [  36 1641]]
# *************** RandomForestClassifier(random_state=0) ***********
#
# [[1446  230]
#  [ 161 1516]]
# *************** AdaBoostClassifier(n_estimators=100, random_state=0) ***********
#
# [[1219  457]
#  [  36 1641]]
# *************** GradientBoostingClassifier(max_depth=2, max_features=2) ***********
#
# [[1200  476]
#  [  23 1654]]
# *************** LogisticRegression() ***********
#
# [[1124  552]
#  [   3 1674]]

# %%
def print_confusion_matrix(model,X_test,y_test,pos_label=True):
  y_pred= model.predict(X_test)

  true_positive=0
  false_positive=0
  true_negative=0
  false_positive=0

  for (pred,true) in zip(y_pred,y_test):
    if pred== pos_label and true==pos_label:
      true_positive +=1
    elif pred== pos_label:
      false_positive +=1

# %%
import matplotlib.pyplot as plt
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]
# Plot
plt.pie(sizes, labels=labels,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
pip install jupyterthemes
